# %%
import yfinance as yf
import numpy as np
import gymnasium as gym
import pandas as pd
import os

# %%
# %%bash
# sudo apt-get update
# sudo apt-get install libsdl2-dev libsdl2-image-dev libsdl2-mixer-dev libsdl2-ttf-dev
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 121
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[2], line 1
# ----> 1 get_ipython().run_cell_magic('bash', '', 'sudo apt-get update\nsudo apt-get install libsdl2-dev libsdl2-image-dev libsdl2-mixer-dev libsdl2-ttf-dev\n')
#
# File ~/anaconda3/lib/python3.13/site-packages/IPython/core/interactiveshell.py:2565, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2564     args = (magic_arg_s, cell)
# -> 2565     result = fn(*args, **kwargs)
#    2567 # The code below prevents the output from being displayed
#    2568 # when using magics with decorator @output_can_be_silenced
#    2569 # when the last Python token in the expression is a ';'.
#
# File ~/anaconda3/lib/python3.13/site-packages/IPython/core/magics/script.py:160, in ScriptMagics._make_script_magic.<locals>.named_script_magic(line, cell)
#     159     line = script
# --> 160 return self.shebang(line, cell)
#
# File ~/anaconda3/lib/python3.13/site-packages/IPython/core/magics/script.py:339, in ScriptMagics.shebang(self, line, cell)
#     338 if args.raise_error:
# --> 339     raise CalledProcessError(p.returncode, cell) from None
#     340 else:
#
# <class 'str'>: (<class 'TypeError'>, TypeError('%d format: a real number is required, not NoneType'))
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# File ~/anaconda3/lib/python3.13/site-packages/IPython/core/interactiveshell.py:2205, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2202         traceback.print_exc()
#    2203         return None
# -> 2205     self._showtraceback(etype, value, stb)
#    2206 if self.call_pdb:
#    2207     # drop into debugger
#    2208     self.debugger(force=True)
#
# File ~/anaconda3/lib/python3.13/site-packages/ipykernel/zmqshell.py:612, in ZMQInteractiveShell._showtraceback(self, etype, evalue, stb)
#     606 sys.stdout.flush()
#     607 sys.stderr.flush()
#     609 exc_content = {
#     610     "traceback": stb,
#     611     "ename": str(etype.__name__),
# --> 612     "evalue": str(evalue),
#     613 }
#     615 dh = self.displayhook
#     616 # Send exception info over pub socket for other clients than the caller
#     617 # to pick up
#
# File ~/anaconda3/lib/python3.13/subprocess.py:154, in CalledProcessError.__str__(self)
#     151         return "Command '%s' died with unknown signal %d." % (
#     152                 self.cmd, -self.returncode)
#     153 else:
# --> 154     return "Command '%s' returned non-zero exit status %d." % (
#     155             self.cmd, self.returncode)
#
# TypeError: %d format: a real number is required, not NoneType
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/anaconda3/lib/python3.13/site-packages/IPython/core/async_helpers.py:128, in _pseudo_sync_runner(coro)
#     120 """
#     121 A runner that does not really allow async execution, and just advance the coroutine.
#     122
#    (...)    125 Credit to Nathaniel Smith
#     126 """
#     127 try:
# --> 128     coro.send(None)
#     129 except StopIteration as exc:
#     130     return exc.value
#
# File ~/anaconda3/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3413, in InteractiveShell.run_cell_async(self, raw_cell, store_history, silent, shell_futures, transformed_cell, preprocessing_exc_tuple, cell_id)
#    3409 exec_count = self.execution_count
#    3410 if result.error_in_exec:
#    3411     # Store formatted traceback and error details
#    3412     self.history_manager.exceptions[exec_count] = (
# -> 3413         self._format_exception_for_storage(result.error_in_exec)
#    3414     )
#    3416 # Each cell is a *single* input, regardless of how many lines it has
#    3417 self.execution_count += 1
#
# File ~/anaconda3/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3474, in InteractiveShell._format_exception_for_storage(self, exception, filename, running_compiled_code)
#    3470         except Exception:
#    3471             # In case formatting fails, fallback to Python's built-in formatting.
#    3472             stb = traceback.format_exception(etype, evalue, tb)
# -> 3474 return {"ename": etype.__name__, "evalue": str(evalue), "traceback": stb}
#
# File ~/anaconda3/lib/python3.13/subprocess.py:154, in CalledProcessError.__str__(self)
#     151         return "Command '%s' died with unknown signal %d." % (
#     152                 self.cmd, -self.returncode)
#     153 else:
# --> 154     return "Command '%s' returned non-zero exit status %d." % (
#     155             self.cmd, self.returncode)
#
# TypeError: %d format: a real number is required, not NoneType

# %%
# !pip install -r 'requirements.txt'
# Out:
# Collecting alpaca_trade_api>=2.1.0 (from -r requirements.txt (line 3))
#   Using cached alpaca_trade_api-3.2.0-py3-none-any.whl.metadata (29 kB)
# Collecting ccxt>=1.90.41 (from -r requirements.txt (line 4))
#   Using cached ccxt-4.5.36-py2.py3-none-any.whl.metadata (139 kB)
# ERROR: Could not find a version that satisfies the requirement libsdl2-dev (from versions: none)
# ERROR: No matching distribution found for libsdl2-dev

# %%
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader

from finrl.config import INDICATORS
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
# Out:
# 2026-02-05 17:19:57.168537: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-05 17:20:02.262694: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-02-05 17:20:08.582519: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# /home/mb0w3n/anaconda3/lib/python3.13/site-packages/keras/src/export/tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
#       3 from finrl.config import INDICATORS
#       4 from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
#
# File ~/anaconda3/lib/python3.13/site-packages/finrl/__init__.py:4
#       1 from __future__ import annotations
#       3 from finrl.test import test
# ----> 4 from finrl.trade import trade
#       5 from finrl.train import train
#
# File ~/anaconda3/lib/python3.13/site-packages/finrl/trade.py:3
#       1 from __future__ import annotations
# ----> 3 from finrl.meta.env_stock_trading.env_stock_papertrading import AlpacaPaperTrading
#       4 from finrl.test import test
#       7 def trade(
#       8     start_date,
#       9     end_date,
#    (...)     22     **kwargs,
#      23 ):
#
# File ~/anaconda3/lib/python3.13/site-packages/finrl/meta/env_stock_trading/env_stock_papertrading.py:7
#       4 import threading
#       5 import time
# ----> 7 import alpaca_trade_api as tradeapi
#       8 import gymnasium as gym
#       9 import numpy as np
#
# ModuleNotFoundError: No module named 'alpaca_trade_api'

# %%
from models.denseModel import trainDense

from sklearn.preprocessing import StandardScaler
from utils.tools import dotdict
from conf import get_train_config

args, setting = get_train_config()

# args = dotdict()

args.sequence_len = 96
args.select_type = 'train'

# %%
def get_data():
        
        scaler = StandardScaler()
        df_raw = pd.read_csv(os.path.join(args.root_path,
                                          args.data_path))
        
        num_train = int(len(df_raw) * 0.7)
        num_test = int(len(df_raw) * 0.2)
        num_vali = len(df_raw) - num_train - num_test

        np_df = df_raw.to_numpy()

        cols_data = df_raw.columns[1:]
        df_data = df_raw[cols_data]

        df_data = df_data.to_numpy()[2:]
        
        col_to_delete = []        

        for i in range(df_data.shape[1]):
            col = df_data[:, i]
            if np.isnan(col).any():
                mean_val = np.nanmean(col)
                col[np.isnan(col)] = mean_val
                df_data[:, i] = col
                print(f'found nan in column {i}, which belongs to {cols_data[i]}, column deleted')

                col_to_delete.append(cols_data[i])

        cols_data = list(set(cols_data) - set(col_to_delete))

        df_data = df_raw[cols_data].to_numpy()[2:]

        return df_data

# %%
data = get_data()
